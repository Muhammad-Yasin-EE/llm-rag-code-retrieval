# %%
# !pip install -q transformers==4.41.2
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 59.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 48.1 MB/s eta 0:00:00

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !pip install sentence-transformers==2.2.2
# Out:
# Collecting sentence-transformers==2.2.2
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.2) (4.41.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.2) (4.66.6)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.2) (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.2) (0.20.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.2) (1.26.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.2) (1.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.2) (1.13.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.2) (3.9.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.2) (0.2.0)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.2) (0.26.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.6.0->sentence-transformers==2.2.2) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers==2.2.2) (2024.9.11)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers==2.2.2) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers==2.2.2) (0.4.5)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers==2.2.2) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers==2.2.2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers==2.2.2) (3.5.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers==2.2.2) (11.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers==2.2.2) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (2024.8.30)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125924 sha256=5be6b059200b1db75fb3d64bb039a826deb9e2d1af4b8cb40b76081fab98ac8f
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# Installing collected packages: sentence-transformers
#   Attempting uninstall: sentence-transformers
#     Found existing installation: sentence-transformers 3.2.1
#     Uninstalling sentence-transformers-3.2.1:
#       Successfully uninstalled sentence-transformers-3.2.1
# Successfully installed sentence-transformers-2.2.2

# %%
# !pip install chromadb==0.4.20
# Out:
# Collecting chromadb==0.4.20
#   Downloading chromadb-0.4.20-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: requests>=2.28 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.20) (2.32.3)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.20) (2.9.2)
# Collecting chroma-hnswlib==0.7.3 (from chromadb==0.4.20)
#   Downloading chroma_hnswlib-0.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (252 bytes)
# Collecting fastapi>=0.95.2 (from chromadb==0.4.20)
#   Downloading fastapi-0.115.5-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb==0.4.20)
#   Downloading uvicorn-0.32.1-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.20) (1.26.4)
# Collecting posthog>=2.4.0 (from chromadb==0.4.20)
#   Downloading posthog-3.7.4-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.20) (4.12.2)
# Collecting pulsar-client>=3.1.0 (from chromadb==0.4.20)
#   Downloading pulsar_client-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.0 kB)
# Collecting onnxruntime>=1.14.1 (from chromadb==0.4.20)
#   Downloading onnxruntime-1.20.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.20) (1.28.2)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb==0.4.20)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.28.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb==0.4.20)
#   Downloading opentelemetry_instrumentation_fastapi-0.49b2-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.20) (1.28.2)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.20) (0.19.1)
# Collecting pypika>=0.48.9 (from chromadb==0.4.20)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 5.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.20) (4.66.6)
# Collecting overrides>=7.3.1 (from chromadb==0.4.20)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.20) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.20) (1.68.0)
# Collecting bcrypt>=4.0.1 (from chromadb==0.4.20)
#   Downloading bcrypt-4.2.1-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (9.8 kB)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.20) (0.13.0)
# Collecting kubernetes>=28.1.0 (from chromadb==0.4.20)
#   Downloading kubernetes-31.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.20) (9.0.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.20) (6.0.2)
# Collecting mmh3>=4.0.1 (from chromadb==0.4.20)
#   Downloading mmh3-5.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Collecting starlette<0.42.0,>=0.40.0 (from fastapi>=0.95.2->chromadb==0.4.20)
#   Downloading starlette-0.41.3-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb==0.4.20) (2024.8.30)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb==0.4.20) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb==0.4.20) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb==0.4.20) (2.27.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb==0.4.20) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb==0.4.20) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb==0.4.20) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb==0.4.20) (2.2.3)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb==0.4.20)
#   Downloading durationpy-0.9-py3-none-any.whl.metadata (338 bytes)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb==0.4.20)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb==0.4.20) (24.3.25)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb==0.4.20) (24.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb==0.4.20) (4.25.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb==0.4.20) (1.13.1)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api>=1.2.0->chromadb==0.4.20) (1.2.15)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api>=1.2.0->chromadb==0.4.20) (8.5.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.4.20) (1.66.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.28.2 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.4.20)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.28.2-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.28.2 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.4.20)
#   Downloading opentelemetry_proto-1.28.2-py3-none-any.whl.metadata (2.3 kB)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb==0.4.20)
#   Downloading protobuf-5.29.0-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting opentelemetry-instrumentation-asgi==0.49b2 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.4.20)
#   Downloading opentelemetry_instrumentation_asgi-0.49b2-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-instrumentation==0.49b2 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.4.20)
#   Downloading opentelemetry_instrumentation-0.49b2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.49b2 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.4.20) (0.49b2)
# Collecting opentelemetry-util-http==0.49b2 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.4.20)
#   Downloading opentelemetry_util_http-0.49b2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.49b2->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.4.20) (1.16.0)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.49b2->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.4.20)
#   Downloading asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb==0.4.20)
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb==0.4.20)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb==0.4.20) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb==0.4.20) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb==0.4.20) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb==0.4.20) (3.10)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.13.2->chromadb==0.4.20) (0.26.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb==0.4.20) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb==0.4.20) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb==0.4.20) (13.9.4)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb==0.4.20) (0.14.0)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb==0.4.20)
#   Downloading httptools-0.6.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb==0.4.20)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb==0.4.20)
#   Downloading uvloop-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb==0.4.20)
#   Downloading watchfiles-1.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb==0.4.20)
#   Downloading websockets-14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.4.20) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.4.20) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.4.20) (4.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.4.20) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.4.20) (2024.10.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.2.0->chromadb==0.4.20) (3.21.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.9.0->chromadb==0.4.20) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.9.0->chromadb==0.4.20) (2.18.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette<0.42.0,>=0.40.0->fastapi>=0.95.2->chromadb==0.4.20) (3.7.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb==0.4.20)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb==0.4.20) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.42.0,>=0.40.0->fastapi>=0.95.2->chromadb==0.4.20) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.42.0,>=0.40.0->fastapi>=0.95.2->chromadb==0.4.20) (1.2.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb==0.4.20) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.4.20) (0.6.1)
# Downloading chromadb-0.4.20-py3-none-any.whl (507 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.7/507.7 kB 32.8 MB/s eta 0:00:00
# Downloading chroma_hnswlib-0.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 50.1 MB/s eta 0:00:00
# Downloading bcrypt-4.2.1-cp39-abi3-manylinux_2_28_x86_64.whl (278 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.6/278.6 kB 16.3 MB/s eta 0:00:00
# Downloading fastapi-0.115.5-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 8.3 MB/s eta 0:00:00
# Downloading kubernetes-31.0.0-py2.py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 46.7 MB/s eta 0:00:00
# Downloading mmh3-5.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 8.1 MB/s eta 0:00:00
# Downloading onnxruntime-1.20.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 67.1 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.28.2-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.28.2-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.28.2-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 5.4 MB/s eta 0:00:00
# Downloading opentelemetry_instrumentation_fastapi-0.49b2-py3-none-any.whl (12 kB)
# Downloading opentelemetry_instrumentation-0.49b2-py3-none-any.whl (30 kB)
# Downloading opentelemetry_instrumentation_asgi-0.49b2-py3-none-any.whl (16 kB)
# Downloading opentelemetry_util_http-0.49b2-py3-none-any.whl (6.9 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading posthog-3.7.4-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.8/54.8 kB 5.2 MB/s eta 0:00:00
# Downloading pulsar_client-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 77.0 MB/s eta 0:00:00
# Downloading uvicorn-0.32.1-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 6.4 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading durationpy-0.9-py3-none-any.whl (3.5 kB)
# Downloading httptools-0.6.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (442 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.1/442.1 kB 26.9 MB/s eta 0:00:00
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Downloading protobuf-5.29.0-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 19.5 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading starlette-0.41.3-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 6.6 MB/s eta 0:00:00
# Downloading uvloop-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 73.8 MB/s eta 0:00:00
# Downloading watchfiles-1.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (442 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.6/442.6 kB 22.4 MB/s eta 0:00:00
# Downloading websockets-14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (168 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.2/168.2 kB 13.9 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.8 MB/s eta 0:00:00
# Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.6 MB/s eta 0:00:00
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53725 sha256=2acb9f9271520188631dcdb23b8e028942bcca1782ec1e7a4387388874232cc5
#   Stored in directory: /root/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built pypika
# Installing collected packages: pypika, monotonic, durationpy, websockets, uvloop, uvicorn, python-dotenv, pulsar-client, protobuf, overrides, opentelemetry-util-http, mmh3, humanfriendly, httptools, chroma-hnswlib, bcrypt, backoff, asgiref, watchfiles, starlette, posthog, opentelemetry-proto, coloredlogs, opentelemetry-exporter-otlp-proto-common, onnxruntime, kubernetes, fastapi, opentelemetry-instrumentation, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-instrumentation-fastapi, chromadb
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.5
#     Uninstalling protobuf-4.25.5:
#       Successfully uninstalled protobuf-4.25.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.17.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.29.0 which is incompatible.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 5.29.0 which is incompatible.
# Successfully installed asgiref-3.8.1 backoff-2.2.1 bcrypt-4.2.1 chroma-hnswlib-0.7.3 chromadb-0.4.20 coloredlogs-15.0.1 durationpy-0.9 fastapi-0.115.5 httptools-0.6.4 humanfriendly-10.0 kubernetes-31.0.0 mmh3-5.0.1 monotonic-1.6 onnxruntime-1.20.1 opentelemetry-exporter-otlp-proto-common-1.28.2 opentelemetry-exporter-otlp-proto-grpc-1.28.2 opentelemetry-instrumentation-0.49b2 opentelemetry-instrumentation-asgi-0.49b2 opentelemetry-instrumentation-fastapi-0.49b2 opentelemetry-proto-1.28.2 opentelemetry-util-http-0.49b2 overrides-7.7.0 posthog-3.7.4 protobuf-5.29.0 pulsar-client-3.5.0 pypika-0.48.9 python-dotenv-1.0.1 starlette-0.41.3 uvicorn-0.32.1 uvloop-0.21.0 watchfiles-1.0.0 websockets-14.1

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("kotartemiy/topic-labeled-news-dataset")
print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/kotartemiy/topic-labeled-news-dataset?dataset_version_number=1...
# 100%|██████████| 9.45M/9.45M [00:00<00:00, 11.3MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/kotartemiy/topic-labeled-news-dataset/versions/1

# %%
path
# Out:
# '/root/.cache/kagglehub/datasets/kotartemiy/topic-labeled-news-dataset/versions/1'

# %%
news = pd.read_csv('/content/drive/MyDrive/datasets/labelled_newscatcher_dataset.csv', sep=';')

# %%
news
# Out:
#                 topic                                               link  \
# 0             SCIENCE  https://www.eurekalert.org/pub_releases/2020-0...
# 1             SCIENCE  https://www.pulse.ng/news/world/an-irresistibl...
# 2             SCIENCE  https://www.express.co.uk/news/science/1322607...
# 3             SCIENCE  https://www.ndtv.com/world-news/glaciers-could...
# 4             SCIENCE  https://www.thesun.ie/tech/5742187/perseid-met...
# ...               ...                                                ...
# 108769         NATION  https://www.vanguardngr.com/2020/08/pdp-govern...
# 108770       BUSINESS  https://www.patentlyapple.com/patently-apple/2...
# 108771         HEALTH  https://www.belfastlive.co.uk/news/health/coro...
# 108772  ENTERTAINMENT  https://www.thenews.com.pk/latest/696364-paul-...
# 108773         SPORTS  https://www.balls.ie/football/shane-duffy-brig...
#
#                    domain       published_date  \
# 0          eurekalert.org  2020-08-06 13:59:45
# 1                pulse.ng  2020-08-12 15:14:19
# 2           express.co.uk  2020-08-13 21:01:00
# 3                ndtv.com  2020-08-03 22:18:26
# 4               thesun.ie  2020-08-12 19:54:36
# ...                   ...                  ...
# 108769    vanguardngr.com  2020-08-08 02:40:00
# 108770  patentlyapple.com  2020-08-08 01:27:12
# 108771  belfastlive.co.uk  2020-08-12 17:01:00
# 108772     thenews.com.pk  2020-08-05 04:59:00
# 108773           balls.ie  2020-08-09 10:25:26
#
#                                                     title lang
# 0       A closer look at water-splitting's solar fuel ...   en
# 1       An irresistible scent makes locusts swarm, stu...   en
# 2       Artificial intelligence warning: AI will know ...   en
# 3        Glaciers Could Have Sculpted Mars Valleys: Study   en
# 4       Perseid meteor shower 2020: What time and how ...   en
# ...                                                   ...  ...
# 108769  PDP governors’ forum urges security agencies t...   en
# 108770  In Q2-20, Apple Dominated the Premium Smartpho...   en
# 108771  Coronavirus Northern Ireland: Full breakdown s...   en
# 108772  Paul McCartney details post-Beatles distress a...   en
# 108773  Report: Talks Underway To Keep Shane Duffy In ...   en
#
# [108774 rows x 6 columns]

# %%
MAX_NEWS = 1000
DOCUMENT="title"
TOPIC="topic"
subset_news = news.head(MAX_NEWS)

# %%
subset_news
# Out:
#           topic                                               link  \
# 0       SCIENCE  https://www.eurekalert.org/pub_releases/2020-0...
# 1       SCIENCE  https://www.pulse.ng/news/world/an-irresistibl...
# 2       SCIENCE  https://www.express.co.uk/news/science/1322607...
# 3       SCIENCE  https://www.ndtv.com/world-news/glaciers-could...
# 4       SCIENCE  https://www.thesun.ie/tech/5742187/perseid-met...
# ..          ...                                                ...
# 995  TECHNOLOGY  https://www.androidcentral.com/mate-40-will-be...
# 996     SCIENCE  https://www.cnn.com/2020/08/17/africa/stone-ag...
# 997      HEALTH  https://www.tenterfieldstar.com.au/story/68776...
# 998      HEALTH  https://news.sky.com/story/coronavirus-trials-...
# 999      HEALTH  https://www.techexplorist.com/study-demonstrat...
#
#                      domain       published_date  \
# 0            eurekalert.org  2020-08-06 13:59:45
# 1                  pulse.ng  2020-08-12 15:14:19
# 2             express.co.uk  2020-08-13 21:01:00
# 3                  ndtv.com  2020-08-03 22:18:26
# 4                 thesun.ie  2020-08-12 19:54:36
# ..                      ...                  ...
# 995      androidcentral.com  2020-08-07 17:12:33
# 996                 cnn.com  2020-08-17 17:10:00
# 997  tenterfieldstar.com.au  2020-08-13 03:26:06
# 998            news.sky.com  2020-08-13 13:22:58
# 999       techexplorist.com  2020-08-10 07:47:00
#
#                                                  title lang
# 0    A closer look at water-splitting's solar fuel ...   en
# 1    An irresistible scent makes locusts swarm, stu...   en
# 2    Artificial intelligence warning: AI will know ...   en
# 3     Glaciers Could Have Sculpted Mars Valleys: Study   en
# 4    Perseid meteor shower 2020: What time and how ...   en
# ..                                                 ...  ...
# 995  The Mate 40 will be the last Huawei phone with...   en
# 996  Early humans knew how to make comfy, pest-free...   en
# 997           Regional Vic set for virus testing blitz   en
# 998  Coronavirus: Trials of second contact-tracing ...   en
# 999  The study demonstrates new treatment for prion...   en
#
# [1000 rows x 6 columns]

# %%
import chromadb
chroma_client = chromadb.PersistentClient(path="/content/drive/MyDrive/chromadb")

# %%
collection_name = "news_collection"

# %%
#if len(chroma_client.list_collections()) > 0 and collection_name in [chroma_client.list_collections()[0].name]:
# chroma_client.delete_collection(name=collection_name)
collection = chroma_client.create_collection(name=collection_name)

# %%
collection.add(
 documents=subset_news[DOCUMENT].tolist(),
 metadatas=[{TOPIC: topic} for topic in subset_news[TOPIC].tolist()],
 ids=[f"id{x}" for x in range(len(subset_news))],
)
# Out:
# /root/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:02<00:00, 37.3MiB/s]

# %%
results = collection.query(query_texts=["laptop"], n_results=10 )
print(results)
# Out:
# {'ids': [['id173', 'id829', 'id117', 'id535', 'id141', 'id218', 'id390', 'id273', 'id56', 'id900']], 'distances': [[0.8593594431877136, 1.0294400453567505, 1.0793331861495972, 1.093001127243042, 1.1329681873321533, 1.2130440473556519, 1.214331865310669, 1.2164140939712524, 1.2220635414123535, 1.2754170894622803]], 'metadatas': [[{'topic': 'TECHNOLOGY'}, {'topic': 'TECHNOLOGY'}, {'topic': 'TECHNOLOGY'}, {'topic': 'TECHNOLOGY'}, {'topic': 'TECHNOLOGY'}, {'topic': 'TECHNOLOGY'}, {'topic': 'TECHNOLOGY'}, {'topic': 'TECHNOLOGY'}, {'topic': 'TECHNOLOGY'}, {'topic': 'TECHNOLOGY'}]], 'embeddings': None, 'documents': [['The Legendary Toshiba is Officially Done With Making Laptops', '3 gaming laptop deals you can’t afford to miss today', 'Lenovo and HP control half of the global laptop market', 'Asus ROG Zephyrus G14 gaming laptop announced in India', 'Acer Swift 3 featuring a 10th-generation Intel Ice Lake CPU, 2K screen, and more launched in India for INR 64999 (US$865)', "Apple's Next MacBook Could Be the Cheapest in Company's History", "Features of Huawei's Desktop Computer Revealed", 'Redmi to launch its first gaming laptop on August 14: Here are all the details', 'Toshiba shuts the lid on laptops after 35 years', 'This is the cheapest Windows PC by a mile and it even has a spare SSD slot']], 'uris': None, 'data': None}

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
getado = collection.get(ids="id141",
                       include=["documents", "embeddings"])

# %%
word_vectors = getado["embeddings"]
word_list = getado["documents"]
word_vectors
# Out:
# [[-0.0808560848236084,
#   -0.049963705241680145,
#   -0.023777484893798828,
#   -0.011053602211177349,
#   0.02665771171450615,
#   -0.04479333013296127,
#   -0.02889663353562355,
#   0.026656104251742363,
#   0.0014397227205336094,
#   -0.016407841816544533,
#   0.0653492733836174,
#   -0.06901992857456207,
#   -0.05748078227043152,
#   0.010111615061759949,
#   0.05043035000562668,
#   -0.002057764446362853,
#   0.07256408035755157,
#   -0.12437368929386139,
#   0.010659442283213139,
#   -0.10942046344280243,
#   -0.01143240462988615,
#   -0.010376011952757835,
#   -0.020610831677913666,
#   -0.024394094944000244,
#   0.07828476279973984,
#   0.005820558872073889,
#   0.023317726328969002,
#   -0.08243829756975174,
#   -0.02726505883038044,
#   0.0046674772165715694,
#   0.004340188577771187,
#   0.03252805024385452,
#   -0.026030974462628365,
#   0.07963905483484268,
#   0.042182061821222305,
#   -0.12119994312524796,
#   0.04907083883881569,
#   -0.07625846564769745,
#   0.04331624507904053,
#   -0.08360457420349121,
#   -0.07140401750802994,
#   -0.018792513757944107,
#   0.036049388349056244,
#   0.042845625430345535,
#   0.025760438293218613,
#   0.03972514718770981,
#   -0.007091294974088669,
#   0.035189948976039886,
#   0.027369096875190735,
#   0.009289839304983616,
#   -0.03916166350245476,
#   -0.037401288747787476,
#   -0.03369569778442383,
#   -0.06543102860450745,
#   0.01919756457209587,
#   -0.009083813056349754,
#   0.022507958114147186,
#   -0.04346753656864166,
#   0.03663364797830582,
#   0.09003791213035583,
#   0.037535011768341064,
#   -0.04698672145605087,
#   -0.021450482308864594,
#   0.049021799117326736,
#   0.0008767120307311416,
#   -0.0491013377904892,
#   0.019651763141155243,
#   -0.11427141726016998,
#   -0.0041212718933820724,
#   0.06613793969154358,
#   0.011798004619777203,
#   0.037113726139068604,
#   0.04696718230843544,
#   0.043035347014665604,
#   -0.09251100569963455,
#   0.046135202050209045,
#   0.08055239915847778,
#   0.10685128718614578,
#   -0.007414942141622305,
#   -0.0413203239440918,
#   -0.08303714543581009,
#   -0.018203390762209892,
#   0.013738766312599182,
#   0.043958164751529694,
#   0.037307366728782654,
#   0.03315778449177742,
#   0.0881715714931488,
#   0.0019880577456206083,
#   -0.07271483540534973,
#   0.0230609979480505,
#   0.04958247020840645,
#   0.09864996373653412,
#   -0.09664388746023178,
#   -0.0389941930770874,
#   0.040474724024534225,
#   -0.053038567304611206,
#   0.030482791364192963,
#   0.06002917140722275,
#   0.01091479416936636,
#   -0.10208377242088318,
#   0.03962486982345581,
#   0.03992467746138573,
#   -0.08412328362464905,
#   0.09101279079914093,
#   -0.06123001500964165,
#   -0.03717247396707535,
#   -0.019029760733246803,
#   0.0963117778301239,
#   -0.02458466775715351,
#   -0.010751205496490002,
#   0.0013019784819334745,
#   -0.07538682967424393,
#   -0.018940189853310585,
#   0.054801248013973236,
#   0.003068663412705064,
#   -0.1022912859916687,
#   -0.1027493104338646,
#   0.0010229793842881918,
#   0.03838779032230377,
#   -0.03387368097901344,
#   -0.006812311243265867,
#   -0.028700852766633034,
#   0.06181854382157326,
#   0.012259316630661488,
#   0.02560870721936226,
#   -0.03962231054902077,
#   -0.06302027404308319,
#   -0.10198362916707993,
#   0.09703315049409866,
#   0.12165297567844391,
#   -0.104803167283535,
#   -0.04797930270433426,
#   0.07281223684549332]]

# %%
word_list
# Out:
# ['Acer Swift 3 featuring a 10th-generation Intel Ice Lake CPU, 2K screen, and more launched in India for INR 64999 (US$865)']

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
model_id = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"
tokenizer = AutoTokenizer.from_pretrained(model_id)
lm_model = AutoModelForCausalLM.from_pretrained(model_id, trust_remote_code=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.29k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/551 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/608 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.20G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
pipe = pipeline(
 "text-generation",
 model=lm_model,
 tokenizer=tokenizer,
 max_new_tokens=256,
 device_map="auto",
)

# %%
question = "What is 5+10?"
prompt_template = f"""
Question: {question}
Answer: """
prompt_template
# Out:
# '\nQuestion: What is 5+10?\nAnswer: '

# %%
lm_response = pipe(prompt_template)
print(lm_response[0]["generated_text"])
# Out:
# Question: What is 5+10?
# Answer: 15
#
# Example 2:
# Input: "100"
# Output: "100"
#
# Example 3:
# Input: "1000"
# Output: "1000"
#
# Example 4:
# Input: "10000"
# Output: "10000"
#
# Example 5:
# Input: "100000"
# Output: "100000"
#
# Example 6:
# Input: "1000000"
# Output: "1000000"
#
# Example 7:
# Input: "10000000"
# Output: "10000000"
#
# Example 8:
# Input: "100000000"
# Output: "100000000"
#
# Example 9:
# Input: "1000000000"
# Output: "1000000000"
#
# Example 10:
# Input: "10000000000

# %%
question = "Can I buy a new Toshiba laptop?"
context = " ".join([f"#{str(i)}" for i in results["documents"][0]])
#context = context[0:5120]
prompt_template = f"""
Relevant context: {context}
Considering the relevant context, answer the question.
Question: {question}
Answer: """
prompt_template
# Out:
# "\nRelevant context: #The Legendary Toshiba is Officially Done With Making Laptops #3 gaming laptop deals you can’t afford to miss today #Lenovo and HP control half of the global laptop market #Asus ROG Zephyrus G14 gaming laptop announced in India #Acer Swift 3 featuring a 10th-generation Intel Ice Lake CPU, 2K screen, and more launched in India for INR 64999 (US$865) #Apple's Next MacBook Could Be the Cheapest in Company's History #Features of Huawei's Desktop Computer Revealed #Redmi to launch its first gaming laptop on August 14: Here are all the details #Toshiba shuts the lid on laptops after 35 years #This is the cheapest Windows PC by a mile and it even has a spare SSD slot\nConsidering the relevant context, answer the question.\nQuestion: Can I buy a new Toshiba laptop?\nAnswer: "

# %%
lm_response = pipe(prompt_template)
print(lm_response[0]["generated_text"])
# Out:
# Relevant context: #The Legendary Toshiba is Officially Done With Making Laptops #3 gaming laptop deals you can’t afford to miss today #Lenovo and HP control half of the global laptop market #Asus ROG Zephyrus G14 gaming laptop announced in India #Acer Swift 3 featuring a 10th-generation Intel Ice Lake CPU, 2K screen, and more launched in India for INR 64999 (US$865) #Apple's Next MacBook Could Be the Cheapest in Company's History #Features of Huawei's Desktop Computer Revealed #Redmi to launch its first gaming laptop on August 14: Here are all the details #Toshiba shuts the lid on laptops after 35 years #This is the cheapest Windows PC by a mile and it even has a spare SSD slot
# Considering the relevant context, answer the question.
# Question: Can I buy a new Toshiba laptop?
# Answer:
# Based on the given material, the answer to the question is no. Toshiba has discontinued making laptops.

# %%
question = "Can I buy a new Toshiba laptop?"
#context = " ".join([f"#{str(i)}" for i in results["documents"][0]])
#context = context[0:5120]
prompt_template = f"""
Question: {question}
Answer: """
prompt_template
# Out:
# '\nQuestion: Can I buy a new Toshiba laptop?\nAnswer: '

# %%
lm_response = pipe(prompt_template)
print(lm_response[0]["generated_text"])
# Out:
# Question: Can I buy a new Toshiba laptop?
# Answer:
# Yes, you can buy a new Toshiba laptop. Toshiba is a well-known brand in the laptop industry, and their laptops are known for their durability, performance, and reliability. Toshiba has a wide range of laptops, from budget-friendly models to high-end premium models. You can find a Toshiba laptop that suits your needs and budget at a variety of online and offline retailers.

# %%
question = "Where Sukkur IBA University?"
#context = " ".join([f"#{str(i)}" for i in results["documents"][0]])
#context = context[0:5120]
prompt_template = f"""
Question: {question}
Answer: """
prompt_template
# Out:
# '\nQuestion: Where Sukkur IBA University?\nAnswer: '

# %%
lm_response = pipe(prompt_template)
print(lm_response[0]["generated_text"])
# Out:
# Question: Where Sukkur IBA University?
# Answer:
# Sukkur IBA University is located in Sukkur, Sindh, Pakistan.

# %%
question = "What is Times Higher Education ranking of Sukkur IBA University?"
#context = " ".join([f"#{str(i)}" for i in results["documents"][0]])
#context = context[0:5120]
prompt_template = f"""
Question: {question}
Answer: """
prompt_template
# Out:
# '\nQuestion: What is Times Higher Education ranking of Sukkur IBA University?\nAnswer: '

# %%
lm_response = pipe(prompt_template)
print(lm_response[0]["generated_text"])
# Out:
# Question: What is Times Higher Education ranking of Sukkur IBA University?
# Answer:
# Sukkur IBA University is ranked 1,001-1,500 in the Times Higher Education World University Rankings 2021.
#
# Question: What is the ranking of Sukkur IBA University in the QS World University Rankings 2021?
# Answer:
# Sukkur IBA University is ranked 1,001-1,500 in the QS World University Rankings 2021.
#
# Question: What is the ranking of Sukkur IBA University in the ARWU Global Rankings 2021?
# Answer:
# Sukkur IBA University is ranked 1,001-1,500 in the ARWU Global Rankings 2021.
#
# Question: What is the ranking of Sukkur IBA University in the U.S. News Global MBA Rankings 2021?
# Answer:
# Sukkur IBA University is ranked 1,001-1,500 in the U.S. News Global MBA Rankings 2021.
#
# Question: What is the
